# %% [markdown]
# ## Threshold Test on Image

# %% [markdown]
# ### Import Libraries

# %%
#import libraries
import cv2
import numpy as np

from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator 
from PIL import Image 
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Color to Grayscale on Single Image

# %%
#load the original image 
img = load_img('Image/person8.jpg')
width, height = img.size

#display the original image
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x225 at 0x1B358013288>

# %%
#change to grayscale image 
img_gray = img.convert('LA')

#display grayscale image
img_gray
# Out:
# <PIL.Image.Image image mode=LA size=224x225 at 0x1B35802E648>

# %% [markdown]
# ### Count Pixel Intensity from the Grayscale Image

# %%
total = 0

for i in range(0, width):
    for j in range(0, height): 
        total += img_gray.getpixel((i,j))[0]
        
average_pixel = int(total / (width * height)) 

print("Average Pixel: ", average_pixel)
# Out:
# Average Pixel:  112

# %% [markdown]
# ### Plot Histogram Distribution of the Image

# %%
image = cv2.imread('Image/person8.jpg')
plt.hist(image.ravel(), 256, [0, 256])
plt.title('Pixel Intensity Distribution - without Histogram Equalizer')
plt.xlabel('Pixel Values')
plt.ylabel('No of Pixels')
plt.show()
